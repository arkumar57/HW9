# %% [markdown]
# # CPSC 330 - Applied Machine Learning
#
# ## Homework 9: Communication
#
# **Due date: See the [Calendar](https://htmlpreview.github.io/?https://github.com/UBC-CS/cpsc330/blob/master/docs/calendar.html)**

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# <div class="alert alert-info">
#
# ## Submission instructions
# <hr>
# rubric={points:2}
#
# Follow the [homework submission instructions](https://github.com/UBC-CS/cpsc330-2024W1/blob/main/docs/homework_instructions.md).
#
# **You may work in a group on this homework and submit your assignment as a group.** Below are some instructions on working as a group.
# - The maximum group size is 2.
# - Use group work as an opportunity to collaborate and learn new things from each other.
# - Be respectful to each other and make sure you understand all the concepts in the assignment well.
# - It's your responsibility to make sure that the assignment is submitted by one of the group members before the deadline.
# - You can find the instructions on how to do group submission on Gradescope [here](https://help.gradescope.com/article/m5qz2xsnjy-student-add-group-members).
#
#
# When you are ready to submit your assignment do the following:
#
# 1. Run all cells in your notebook to make sure there are no errors by doing `Kernel -> Restart Kernel and Clear All Outputs` and then `Run -> Run All Cells`.
# 2. Notebooks with cell execution numbers out of order or not starting from “1” will have marks deducted. Notebooks without the output displayed may not be graded at all (because we need to see the output in order to grade your work).
# 3. Upload the assignment using Gradescope's drag and drop tool. Check out this [Gradescope Student Guide](https://lthub.ubc.ca/guides/gradescope-student-guide/) if you need help with Gradescope submission.
# 4. Make sure that the plots and output are rendered properly in your submitted file.
# 5. If the .ipynb file is too big and doesn't render on Gradescope, also upload a pdf or html in addition to the .ipynb.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 1: Survival analysis
# <hr>
#
# rubric={points:6}
#
# The following questions pertain to Lecture 21 on survival analysis. We'll consider the use case of customer churn analysis.
#
# 1. What is the problem with simply labeling customers are "churned" or "not churned" and using standard supervised learning techniques?
# 2. Consider customer A who just joined last week vs. customer B who has been with the service for a year. Who do you expect will leave the service first: probably customer A, probably customer B, or we don't have enough information to answer? Briefly explain your answer.
# 3. If a customer's survival function is almost flat during a certain period, how do we interpret that?

# %% [markdown]
# 1) Simply labeling will not solve the sole purpose of our analysis which is to find at what frame of time will a certain customer churn so the relevant business can send out promotional pricing and carry out strategies to stop the customer from churning in order to continue getting their business.
# 2) Customer A is likely to leave the earlier as their is chance they are just checking out the free trail and may not stay with the service if they don't like it. However, since Customer B has been with company for a year, they are likely to stay longer since they must be satisfied with the service which has lead them to continue to be with the company.
# 3) This means they are not more or less likely to drop the service over that period of time.

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 2: Communication
# <hr>

# %% [markdown]
# ### 2.1 Blog post
# rubric={points:26}
#
# Write up your analysis from hw5 or any other assignment or your side project on machine learning in a "blog post" or report format. It's fine if you just write it here in this notebook. Alternatively, you can publish your blog post publicly and include a link here. (See exercise 2.3.) The target audience for your blog post is someone like yourself right before you took this course. They don't necessarily have ML knowledge, but they have a solid foundation in technical matters. The post should focus on explaining **your results and what you did** in a way that's understandable to such a person, **not** a lesson trying to teach someone about machine learning. Again: focus on the results and why they are interesting; avoid pedagogical content.
#
# Your post must include the following elements (not necessarily in this order):
#
# - Description of the problem/decision.
# - Description of the dataset (the raw data and/or some EDA).
# - Description of the model.
# - Description your results, both quantitatively and qualitatively. Make sure to refer to the original problem/decision.
# - A section on caveats, describing at least 3 reasons why your results might be incorrect, misleading, overconfident, or otherwise problematic. Make reference to your specific dataset, model, approach, etc. To check that your reasons are specific enough, make sure they would not make sense, if left unchanged, to most students' submissions; for example, do not just say "overfitting" without explaining why you might be worried about overfitting in your specific case.
# - At least 3 visualizations. These visualizations must be embedded/interwoven into the text, not pasted at the end. The text must refer directly to each visualization. For example "as shown below" or "the figure demonstrates" or "take a look at Figure 1", etc. It is **not** sufficient to put a visualization in without referring to it directly.
#
# A reasonable length for your entire post would be **800 words**. The maximum allowed is **1000 words**.

# %% [markdown]
# #### Example blog posts
#
# Here are some examples of applied ML blog posts that you may find useful as inspiration. The target audiences of these posts aren't necessarily the same as yours, and these posts are longer than yours, but they are well-structured and engaging. You are **not required to read these** posts as part of this assignment - they are here only as examples if you'd find that useful.
#
# From the UBC Master of Data Science blog, written by a past student:
#
# - https://ubc-mds.github.io/2019-07-26-predicting-customer-probabilities/
#
# This next one uses R instead of Python, but that might be good in a way, as you can see what it's like for a reader that doesn't understand the code itself (the target audience for your post here):
#
# - https://rpubs.com/RosieB/taylorswiftlyricanalysis
#
# Finally, here are a couple interviews with winners from Kaggle competitions. The format isn't quite the same as a blog post, but you might find them interesting/relevant:
#
# - https://medium.com/kaggle-blog/instacart-market-basket-analysis-feda2700cded
# - https://medium.com/kaggle-blog/winner-interview-with-shivam-bansal-data-science-for-good-challenge-city-of-los-angeles-3294c0ed1fb2

# %% [markdown]
# #### A note on plagiarism
#
# You may **NOT** include text or visualizations that were not written/created by you. If you are in any doubt as to what constitutes plagiarism, please just ask. For more information see the [UBC Academic Misconduct policies](http://www.calendar.ubc.ca/vancouver/index.cfm?tree=3,54,111,959). Please don't copy this from somewhere or ask Generative AI to write it for you 🙏.

# %% [markdown]
# **Description of the problem/decision**
#
# Airbnb serves as a marketplace connecting hosts and guests, offering a variety of listings within neighborhoods for short-term stays. Our goal is to predict the number of reviews a particular listing might receive within a month. This prediction can help gauge the potential popularity of future listings before they go live, enabling hosts to create more appealing and competitive listings.
#
# **Description of the dataset (the raw data and/or some EDA)**
#
# The dataset provided to train the model initially contained 16 features. For better efficiency of the model, we excluded the features that were not relevant for the prediction, such as `Host ID`, `Host Name`, and `ID`. Also, features like `Last Review Date` and the total `Number of Reviews` for a property were removed to avoid data leakage. Data leakage is a situation where the model has access to information to make predictions artificially easy, which would compromise its applicability in the real world. Additionally, there were serious outliers in several of the numerical features ("price", "minimum_nights", and "calculated_host_listings" have a few values which drastically expand the range of the feature). Outliers have a strong effect on linear models, but also make standard scaling less effective.Hence we implemented a logistic scaler on these features. Latitude and longitude features seemed to have some predictive value, but didn't have a linear connection with the target value. Instead, we made them categorical features by binning them.
#
# **Description of the model**
#
# Starting of with the base model for implementation, we applied dummy classifier. Unsurprisingly, the model generated very poor results. Unfortunately, linear models like Ridge also gave poor results. We played around with the alpha value as we expected some issues with outliers but there didn't seem to be a hyperparameter that gives a high test or train score, suggesting that the data would do better with a non-linear model.
#
# Non-linear models were an improvement! Even the basic DecisionTreeRegressor was doing significantly better than Ridge. The test scores were still quite low but clustering showed some moderate success, with both RandomForestRegressor and LGBMRegressor showing test scores of around .4.
#
# Conclusively, we found LBGMRegressor to be the best performing model onto our data because it has a slightly higher average test score than RandomForestRegressor as well as a lower train score.
#
# **Description of results**
#
# The results of the study showed some interesting observations. Unsurprisingly, price and minimum nights showed a strong affect on the data, with a high price having a negative affect on reviews per month and high minumum nights also having a negative affect. Surprisingly however, 365 availability has a very large affect! Looking at a few of the data points in a SHAP plot shows some interesting relationships however! It seems that the feature was rated so highly despite not showing a strong predictive value in the scatter plot, was because a score of 0 has a very large negative affect on reviews per month. This is unsurprising but also suggests a general issue with the target value and how it favors certain properties in what is possibly a confounding way.

# %%
from IPython.display import Image

# %%
from IPython.display import Image
Image("metrics.png")

# %%
from IPython.display import Image
Image("shap.png")

# %% [markdown]
# **Concerns**
#
# While our overall error was not terrible (see figure Above), here are several factors that may have contributed to potentially misleading results. First, the target value, reviews per month, has a substantial issue with how it was calculated. The problem is that this number is generated by dividing total number of reviews by total months open. Because AirB&Bs often have a period of inactivity where they have no guests and thus no reviews, many AirB&Bs that are open for more than a few months have a substantially lower target value than AirB&Bs which have just opened. The graph which compares `Last Review` to `Reviews per Month` below demonstrates this effect, which damages the whole dataset as our target value can be influenced by a feature that really has nothing to do with what makes an AirB&B popular. To minimize the effect of this, we dropped the `Last Review` feature the data we fed into the model, but the effect of this underlying issue could still be a problem with the dataset.

# %%
from IPython.display import Image
Image("year.png")

# %% [markdown]
# Additionally, availability 365 seemed to have an outsized effect in the SHAP analysis but had a very unclear pattern in relation to the target value (see figure below). It's unclear if this is an issue, but it is surprising and suggests an unnoticed correlation or confound that might have needed to have been accounted for during the preprocessing stage.

# %%
from IPython.display import Image
Image("365.png")

# %% [markdown]
# Lastly, we needed to accommodate for some of the  outliers in the dataset. While we attempted to do this by using a logistic scaler transformation as opposed to a standard scaler transformation, it's possible that their presence and subsequent transformations could have caused some scaling issues when compared to other numerical features without extreme outliers. Additionally, logistic scaling makes the features transformed by it much harder to specifically interpret, as transforming scaled units back to their original values is much more difficult to do with a logistic scaler as opposed to a standard scaler.

# %% [markdown]
# <br><br>

# %% [markdown]
# ### 2.2 Effective communication technique
# rubric={points:4}
#
# Describe one effective communication technique that you used in your post, or an aspect of the post that you are particularly satisfied with. (Max 3 sentences.)

# %% [markdown]
# Ans: The use of visual representations at different points within post makes the essay more appealing and intresting from time to time in case the reader losses the interest on the way and helps in explaining the main findings in a compelling and effective way.

# %% [markdown]
# <br><br>

# %% [markdown]
# ### (optional, not for marks) 2.3
#
# Publish your blog post from 1.1 publicly using a tool like [Quarto](https://quarto.org/), or somewhere like medium.com, and paste a link here. Be sure to pick a tool in which code and code output look reasonable. This link could be a useful line on your resume!

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# ## Exercise 3: Your takeaway from the course
# rubric={points:2}
#
# **Your tasks:**
#
# - Reflect on your journey through this course. Please identify and elaborate on at least three key concepts or experiences where you had an "aha" moment. How would you use the concepts learned in this course in your personal projects or how would you approach your past projects differently based on the insights gained in this course? We encourage you to dig deep and share your genuine reflections.
#
# > Please write thoughtful answers. We are looking forward to reading them 🙂.

# %% [markdown]
# 1) Learning about new ways to do exploratory data analysis taught us new ways of cleaning up the raw data and making the most out of it and will be useful in future data analysis related projects.
# 2) The importance of preprocessing was another major takeaway for me! The importance of working with a dataset first and tweaking it so that the model can actually extract useful data from it is something I worked with briefly during my Co-op term, but actually seeing the way that transformations can affect the utility of a dataset did a great job at shifting my perspective from upgrading the model to updrading the data. This to me is a much more productive approach.
# 3) A major takeaway from the course is the emphasis that a model is only as good as it's dataset. As impressive as some machine learning models are, as advanced a strategy as transfer learning is, and as many algorithms identify almost invisible patterns in noisy data, they can only do some much with what they are given. Despite the current sizzle, machine learning is not magic, and while it may just be confirmation bias from me desiring a world that continues to have a human touch, it does suggest that machine learning will not rapidly replicate itself into any kind of AI overlord; at least with it's current approach. There exist limitations to even the most advanced machine learning algorithms, and understanding those limitations allows you to use AI tools more responsibily and also more efficiently (instead of repeatedly prompting it repetaedly to do something it's not very good at).

# %% [markdown]
# <br><br><br><br>

# %% [markdown]
# **Before submitting your assignment, please make sure you have followed all the instructions in the Submission instructions section at the top.**

# %% [markdown]
# ### Congratulations 👏👏
#
# That's all for the assignments! Congratulations on finishing all homework assignments!

# %%
from IPython.display import Image

Image("img/eva-congrats.png")
